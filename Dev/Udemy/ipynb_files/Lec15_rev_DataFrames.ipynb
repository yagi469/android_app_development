# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
# NFLのデータをサンプルとして使います。
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
# クリップボードから読み込むことが可能です。
nfl_frame = pd.read_clipboard(sep='\t')

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles  1,220  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1950   NFC West
# 8               1925   NFC East
# 9               1960   AFC West
# 10              1960   AFC West
# 11              1933  AFC North
# 12              1953  AFC South
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1932   NFC East
# 17              1960   AFC West
# 18              1933   NFC East
# 19              1995  NFC South
# 20              1950  AFC North
# 21              1960  AFC South
# 22              1960   AFC East
# 23              1967  NFC South
# 24              1930  NFC North
# 25              2002  AFC South
# 26              1960   AFC East
# 27              1968  AFC North
# 28              1966  NFC South
# 29              1995  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
# 列（カラム）の名前が.columnsでわかります。
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
#@ もとデータの列の名前が変更されています。
nfl_frame['First NFL Season']
# Out:
# 0     1960
# 1     1921
# 2     1960
# 3     1920
# 4     1996
# 5     1966
# 6     1961
# 7     1950
# 8     1925
# 9     1960
# 10    1960
# 11    1933
# 12    1953
# 13    1960
# 14    1976
# 15    1937
# 16    1932
# 17    1960
# 18    1933
# 19    1995
# 20    1950
# 21    1960
# 22    1960
# 23    1967
# 24    1930
# 25    2002
# 26    1960
# 27    1968
# 28    1966
# 29    1995
# 30    1920
# 31    1976
# Name: First NFL Season, dtype: int64

# %%
# オブジェクトの属性のような書き方も可能
nfl_frame.Team
# Out:
# 0           Dallas Cowboys
# 1        Green Bay Packers
# 2     New England Patriots
# 3            Chicago Bears
# 4         Baltimore Ravens
# 5           Miami Dolphins
# 6        Minnesota Vikings
# 7      San Francisco 49ers
# 8          New York Giants
# 9           Denver Broncos
# 10      Kansas City Chiefs
# 11     Pittsburgh Steelers
# 12      Indianapolis Colts
# 13       Las Vegas Raiders
# 14        Seattle Seahawks
# 15        Los Angeles Rams
# 16     Washington Redskins
# 17    Los Angeles Chargers
# 18     Philadelphia Eagles
# 19       Carolina Panthers
# 20        Cleveland Browns
# 21        Tennessee Titans
# 22           Buffalo Bills
# 23      New Orleans Saints
# 24           Detroit Lions
# 25          Houston Texans
# 26           New York Jets
# 27      Cincinnati Bengals
# 28         Atlanta Falcons
# 29    Jacksonville Jaguars
# 30       Arizona Cardinals
# 31    Tampa Bay Buccaneers
# Name: Team, dtype: object

# %%
# 特定のカラムで新しいDataFrameを作る
DataFrame(nfl_frame,columns=['Team','First NFL Season','Total Games'])
# Out:
#                     Team  First NFL Season  Total Games
# 0         Dallas Cowboys              1960          NaN
# 1      Green Bay Packers              1921          NaN
# 2   New England Patriots              1960          NaN
# 3          Chicago Bears              1920          NaN
# 4       Baltimore Ravens              1996          NaN
# 5         Miami Dolphins              1966          NaN
# 6      Minnesota Vikings              1961          NaN
# 7    San Francisco 49ers              1950          NaN
# 8        New York Giants              1925          NaN
# 9         Denver Broncos              1960          NaN
# 10    Kansas City Chiefs              1960          NaN
# 11   Pittsburgh Steelers              1933          NaN
# 12    Indianapolis Colts              1953          NaN
# 13     Las Vegas Raiders              1960          NaN
# 14      Seattle Seahawks              1976          NaN
# 15      Los Angeles Rams              1937          NaN
# 16   Washington Redskins              1932          NaN
# 17  Los Angeles Chargers              1960          NaN
# 18   Philadelphia Eagles              1933          NaN
# 19     Carolina Panthers              1995          NaN
# 20      Cleveland Browns              1950          NaN
# 21      Tennessee Titans              1960          NaN
# 22         Buffalo Bills              1960          NaN
# 23    New Orleans Saints              1967          NaN
# 24         Detroit Lions              1930          NaN
# 25        Houston Texans              2002          NaN
# 26         New York Jets              1960          NaN
# 27    Cincinnati Bengals              1968          NaN
# 28       Atlanta Falcons              1966          NaN
# 29  Jacksonville Jaguars              1995          NaN
# 30     Arizona Cardinals              1920          NaN
# 31  Tampa Bay Buccaneers              1976          NaN

# %%
DataFrame(nfl_frame,columns=['Team','First NFL Season','Total Games','Stadium'])
# Out:
#                     Team  First NFL Season  Total Games  Stadium
# 0         Dallas Cowboys              1960          NaN      NaN
# 1      Green Bay Packers              1921          NaN      NaN
# 2   New England Patriots              1960          NaN      NaN
# 3          Chicago Bears              1920          NaN      NaN
# 4       Baltimore Ravens              1996          NaN      NaN
# 5         Miami Dolphins              1966          NaN      NaN
# 6      Minnesota Vikings              1961          NaN      NaN
# 7    San Francisco 49ers              1950          NaN      NaN
# 8        New York Giants              1925          NaN      NaN
# 9         Denver Broncos              1960          NaN      NaN
# 10    Kansas City Chiefs              1960          NaN      NaN
# 11   Pittsburgh Steelers              1933          NaN      NaN
# 12    Indianapolis Colts              1953          NaN      NaN
# 13     Las Vegas Raiders              1960          NaN      NaN
# 14      Seattle Seahawks              1976          NaN      NaN
# 15      Los Angeles Rams              1937          NaN      NaN
# 16   Washington Redskins              1932          NaN      NaN
# 17  Los Angeles Chargers              1960          NaN      NaN
# 18   Philadelphia Eagles              1933          NaN      NaN
# 19     Carolina Panthers              1995          NaN      NaN
# 20      Cleveland Browns              1950          NaN      NaN
# 21      Tennessee Titans              1960          NaN      NaN
# 22         Buffalo Bills              1960          NaN      NaN
# 23    New Orleans Saints              1967          NaN      NaN
# 24         Detroit Lions              1930          NaN      NaN
# 25        Houston Texans              2002          NaN      NaN
# 26         New York Jets              1960          NaN      NaN
# 27    Cincinnati Bengals              1968          NaN      NaN
# 28       Atlanta Falcons              1966          NaN      NaN
# 29  Jacksonville Jaguars              1995          NaN      NaN
# 30     Arizona Cardinals              1920          NaN      NaN
# 31  Tampa Bay Buccaneers              1976          NaN      NaN

# %%
# 先頭だけを表示
nfl_frame.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    914  520   388     6  0.572
# 1     2     Green Bay Packers  1,368  756   574    38  0.567
# 2     3  New England Patriots    916  512   395     9  0.564
# 3     4         Chicago Bears  1,402  769   591    42  0.563
# 4     5      Baltimore Ravens    384  214   169     1  0.559
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
#最後だけを表示
nfl_frame.tail()
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division
# 27              1968  AFC North
# 28              1966  NFC South
# 29              1995  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
#@ ixメソッドは利用できなくなりました。
# nfl_frame.ix[3]
nfl_frame.iloc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,402
# Won                           769
# Lost                          591
# Tied                           42
# Pct.                        0.563
# First NFL Season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
# 列全体に値を代入
nfl_frame['Stadium'] = "Levi's Stadium" #文字列内に「'」があるので、全体は「”」で囲む

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles  1,220  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division         Stadium
# 0               1960   NFC East  Levi's Stadium
# 1               1921  NFC North  Levi's Stadium
# 2               1960   AFC East  Levi's Stadium
# 3               1920  NFC North  Levi's Stadium
# 4               1996  AFC North  Levi's Stadium
# 5               1966   AFC East  Levi's Stadium
# 6               1961  NFC North  Levi's Stadium
# 7               1950   NFC West  Levi's Stadium
# 8               1925   NFC East  Levi's Stadium
# 9               1960   AFC West  Levi's Stadium
# 10              1960   AFC West  Levi's Stadium
# 11              1933  AFC North  Levi's Stadium
# 12              1953  AFC South  Levi's Stadium
# 13              1960   AFC West  Levi's Stadium
# 14              1976   NFC West  Levi's Stadium
# 15              1937   NFC West  Levi's Stadium
# 16              1932   NFC East  Levi's Stadium
# 17              1960   AFC West  Levi's Stadium
# 18              1933   NFC East  Levi's Stadium
# 19              1995  NFC South  Levi's Stadium
# 20              1950  AFC North  Levi's Stadium
# 21              1960  AFC South  Levi's Stadium
# 22              1960   AFC East  Levi's Stadium
# 23              1967  NFC South  Levi's Stadium
# 24              1930  NFC North  Levi's Stadium
# 25              2002  AFC South  Levi's Stadium
# 26              1960   AFC East  Levi's Stadium
# 27              1968  AFC North  Levi's Stadium
# 28              1966  NFC South  Levi's Stadium
# 29              1995  AFC South  Levi's Stadium
# 30              1920   NFC West  Levi's Stadium
# 31              1976  NFC South  Levi's Stadium

# %%
#@ もとのデータの長さが変わっている増す。
# nfl_frame["Stadium"] = np.arange(6)
nfl_frame["Stadium"] = np.arange(32)
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles  1,220  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division  Stadium
# 0               1960   NFC East        0
# 1               1921  NFC North        1
# 2               1960   AFC East        2
# 3               1920  NFC North        3
# 4               1996  AFC North        4
# 5               1966   AFC East        5
# 6               1961  NFC North        6
# 7               1950   NFC West        7
# 8               1925   NFC East        8
# 9               1960   AFC West        9
# 10              1960   AFC West       10
# 11              1933  AFC North       11
# 12              1953  AFC South       12
# 13              1960   AFC West       13
# 14              1976   NFC West       14
# 15              1937   NFC West       15
# 16              1932   NFC East       16
# 17              1960   AFC West       17
# 18              1933   NFC East       18
# 19              1995  NFC South       19
# 20              1950  AFC North       20
# 21              1960  AFC South       21
# 22              1960   AFC East       22
# 23              1967  NFC South       23
# 24              1930  NFC North       24
# 25              2002  AFC South       25
# 26              1960   AFC East       26
# 27              1968  AFC North       27
# 28              1966  NFC South       28
# 29              1995  AFC South       29
# 30              1920   NFC West       30
# 31              1976  NFC South       31

# %%
# SeriesをDataFrameに追加する
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium']=stadiums
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles  1,220  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division         Stadium
# 0               1960   NFC East    AT&T Stadium
# 1               1921  NFC North             NaN
# 2               1960   AFC East             NaN
# 3               1920  NFC North             NaN
# 4               1996  AFC North  Levi's Stadium
# 5               1966   AFC East             NaN
# 6               1961  NFC North             NaN
# 7               1950   NFC West             NaN
# 8               1925   NFC East             NaN
# 9               1960   AFC West             NaN
# 10              1960   AFC West             NaN
# 11              1933  AFC North             NaN
# 12              1953  AFC South             NaN
# 13              1960   AFC West             NaN
# 14              1976   NFC West             NaN
# 15              1937   NFC West             NaN
# 16              1932   NFC East             NaN
# 17              1960   AFC West             NaN
# 18              1933   NFC East             NaN
# 19              1995  NFC South             NaN
# 20              1950  AFC North             NaN
# 21              1960  AFC South             NaN
# 22              1960   AFC East             NaN
# 23              1967  NFC South             NaN
# 24              1930  NFC North             NaN
# 25              2002  AFC South             NaN
# 26              1960   AFC East             NaN
# 27              1968  AFC North             NaN
# 28              1966  NFC South             NaN
# 29              1995  AFC South             NaN
# 30              1920   NFC West             NaN
# 31              1976  NFC South             NaN

# %%
# 列を消すことも可能
del nfl_frame['Stadium']
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles  1,220  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1950   NFC West
# 8               1925   NFC East
# 9               1960   AFC West
# 10              1960   AFC West
# 11              1933  AFC North
# 12              1953  AFC South
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1932   NFC East
# 17              1960   AFC West
# 18              1933   NFC East
# 19              1995  NFC South
# 20              1950  AFC North
# 21              1960  AFC South
# 22              1960   AFC East
# 23              1967  NFC South
# 24              1930  NFC North
# 25              2002  AFC South
# 26              1960   AFC East
# 27              1968  AFC North
# 28              1966  NFC South
# 29              1995  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
# 辞書からDataFramesを作ることもできます。
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}

city_frame = DataFrame(data)

#Show
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
# pandas.DataFrameの機能の全体は、Webで確認できます。
#@ そのままでも大丈夫ですが、URLが若干変更さています。
# website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
website = 'https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
